# %% [markdown]
# <a href="https://colab.research.google.com/github/kuraninaov/olga/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={"Имя":["Анна", "Борис", None, "Джон"], "Возраст": [28, 30, 45, None]}
df=pd.DataFrame(data)
df
# Out:
#      Имя  Возраст
# 0   Анна     28.0
# 1  Борис     30.0
# 2   None     45.0
# 3   Джон      NaN

# %%
df.isnull()
# Out:
#      Имя  Возраст
# 0  False    False
# 1  False    False
# 2   True    False
# 3  False     True

# %%
x=df.isnull()
df.isnull().loc[x["Имя"]==True]
# Out:
#     Имя  Возраст
# 2  True    False

# %%
1+1
# Out:
# 2
